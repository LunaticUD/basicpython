# %%
# TODO:导入包
import os 
import pandas as pd
import matplotlib.pyplot as plt

# TODO:设置
os.chdir("D:\Text\Statistic_python\example\chap04")

# %% [markdown]
# ### 平均数
# > 一组数据相加后除以数据个数得到的结果
#
# #### 计算公式为：
# $$\bar{x} = \frac{x_{1}+x_{2}+\dots+x_{n}}{n} = \frac{\sum_{i=1}^{n} x_{i}}{n}$$
