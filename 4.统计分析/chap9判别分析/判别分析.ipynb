# %%
import pandas as pd
import numpy as np

# %%
# 导入数据
df = pd.read_excel('data11_10.xlsx', header=None)

# %%
df1 = df[df[5]==1]
df2 = df[df[5]==2]
G1 = df1.values[:, :-1].T.astype(float)     # 变量为行，样本为列
G2 = df2.values[:, :-1].T.astype(float)
# Out:
# array([[  8.11,   9.36,   9.85,   2.55,   6.01,   9.46,   4.11,   8.9 ,
#           7.71,   7.51],
#        [261.01, 185.39, 249.58, 137.13, 231.34, 231.38, 260.25, 259.51,
#         273.84, 303.59],
#        [ 13.23,   9.02,  15.61,   9.21,  14.27,  13.03,  14.72,  14.16,
#          16.01,  19.14],
#        [  5.46,   5.66,   6.06,   6.11,   5.21,   4.88,   5.36,   4.91,
#           5.15,   5.7 ],
#        [  7.36,   5.99,   6.11,   4.35,   8.79,   8.53,  10.02,   9.79,
#           8.79,   8.53]])
