# %%
#FIXME:错误的模型验证 - 用了相同的数据
# 加载数据
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
# 选择模型和超参数
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)
# 训练数据
model.fit(X,y)
y_model = model.predict(X)
# 计算模型的准确度
from sklearn.metrics import accuracy_score
accuracy_score(y,y_model)
# Out:
# 1.0

# %%
#NOTE:模型验证正确方法：留出集 train_test_split - 但模型已失去部分训练的机会
# 加载数据
from sklearn.model_selection import train_test_split
X1,X2,y1,y2 = train_test_split(X,y,random_state=0,train_size=0.5)
# 用模型拟合训练数据
model.fit(X1,y1)
# 评估模型准确度
from sklearn.metrics import accuracy_score
y2_model = model.predict(X2)
accuracy_score(y2,y2_model)
# Out:
# 0.9066666666666666

# %%
#NOTE:模型验证正确方法：交叉验证 - 拟合
# 两轮交叉验证
# 用模型拟合交叉训练预测数据
y2_model = model.fit(X1,y1).predict(X2)
y1_model = model.fit(X2,y2).predict(X1)
# 评估模型准确度
import numpy as np
from sklearn.metrics import accuracy_score
print((accuracy_score(y1,y1_model)+accuracy_score(y2,y2_model))/2)
# Out:
# 0.9333333333333333

# %%
# 五轮交叉验证
# 加载数据
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
# 选择模型和超参数
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)
# 评估模型准确度
from sklearn.model_selection import cross_val_score
cross_val_score(model,X,y,cv=5).mean()
# Out:
# np.float64(0.96)

# %%
# LOO交叉检验
# 加载数据
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target
# 选择模型和超参数
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=1)
# 评估模型准确度
from sklearn.model_selection import LeaveOneOut
loo = LeaveOneOut()  # 正确：无参数
cross_val_score(model,X,y,cv=loo).mean()
# Out:
# np.float64(0.96)
