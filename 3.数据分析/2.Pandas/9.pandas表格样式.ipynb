# %%
import pandas as pd
from tabulate import tabulate

# creating a DataFrame
dict = {
    "Students": ["Intel Dell Laptops", "HP Laptops", "Lenavo Laptops", "Acer Laptops"],
    "Price dollar": [350, 300, 400, 250],
    "Percentage Sale": [83, 99, 84, 76],
}
dataframe = pd.DataFrame(dict)

# displaying the DataFrame
# print(tabulate(dataframe, headers="keys", tablefmt="pretty"))
# print(tabulate(dataframe, headers="keys", tablefmt="plain"))
# print(tabulate(dataframe, headers="keys", tablefmt="simple"))
# print(tabulate(dataframe, headers="keys", tablefmt="github"))
# print(tabulate(dataframe, headers="keys", tablefmt="grid"))
print(tabulate(dataframe, headers="keys", tablefmt="fancy_grid"))
# print(tabulate(dataframe, headers="keys", tablefmt="pipe"))
# print(tabulate(dataframe, headers="keys", tablefmt="orgtbl"))
# print(tabulate(dataframe, headers="keys", tablefmt="jira"))
# print(tabulate(dataframe, headers="keys", tablefmt="presto"))
# print(tabulate(dataframe, headers="keys", tablefmt="psql"))
# print(tabulate(dataframe, headers="keys", tablefmt="rst"))
# print(tabulate(dataframe, headers="keys", tablefmt="mediawiki"))
# print(tabulate(dataframe, headers="keys", tablefmt="moinmoin"))
# print(tabulate(dataframe, headers="keys", tablefmt="youtrack"))
# print(tabulate(dataframe, headers="keys", tablefmt="html"))
# print(tabulate(dataframe, headers="keys", tablefmt="latex"))
# print(tabulate(dataframe, headers="keys", tablefmt="latex_raw"))
# print(tabulate(dataframe, headers="keys", tablefmt="latex_booktabs"))
# print(tabulate(dataframe, headers="keys", tablefmt="textile"))
# Out:
# ╒════╤════════════════════╤════════════════╤═══════════════════╕
# │    │ Students           │   Price dollar │   Percentage Sale │
# ╞════╪════════════════════╪════════════════╪═══════════════════╡
# │  0 │ Intel Dell Laptops │            350 │                83 │
# ├────┼────────────────────┼────────────────┼───────────────────┤
# │  1 │ HP Laptops         │            300 │                99 │
# ├────┼────────────────────┼────────────────┼───────────────────┤
# │  2 │ Lenavo Laptops     │            400 │                84 │
# ├────┼────────────────────┼────────────────┼───────────────────┤
# │  3 │ Acer Laptops       │            250 │                76 │
# ╘════╧════════════════════╧════════════════╧═══════════════════╛
