# %%
import pandas as pd 
#NOTE: 数据读取
df = pd.read_excel('https://gairuo.com/file/data/team.xlsx')
df
# Out:
#         name team  Q1  Q2  Q3  Q4
# 0      Liver    E  89  21  24  64
# 1       Arry    C  36  37  37  57
# 2        Ack    A  57  60  18  84
# 3      Eorge    C  93  96  71  78
# 4        Oah    D  65  49  61  86
# ..       ...  ...  ..  ..  ..  ..
# 95   Gabriel    C  48  59  87  74
# 96   Austin7    C  21  31  30  43
# 97  Lincoln4    C  98  93   1  20
# 98       Eli    E  11  74  58  91
# 99       Ben    E  21  43  41  74
#
# [100 rows x 6 columns]

# %%
# NOTE:数据整体描述
df.shape # (100, 6) 查看行数和列数
# Out:
# (100, 6)

# %%
df.info() # 查看索引、数据类型和内存信息
# 显示有数据类型、索引情况、行列数、各字段数据类型、内存占用等
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    100 non-null    object
#  1   team    100 non-null    object
#  2   Q1      100 non-null    int64
#  3   Q2      100 non-null    int64
#  4   Q3      100 non-null    int64
#  5   Q4      100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe() # 查看数值型列的汇总统计
# 会计算出各数字字段的总数、平均数、标准差、最大最小值和四分位数
# Out:
#                Q1          Q2          Q3          Q4
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.200000   52.550000   52.670000   52.780000
# std     29.962603   29.845181   26.543677   27.818524
# min      1.000000    1.000000    1.000000    2.000000
# 25%     19.500000   26.750000   29.500000   29.500000
# 50%     51.500000   49.500000   55.000000   53.000000
# 75%     74.250000   77.750000   76.250000   75.250000
# max     98.000000   99.000000   99.000000   99.000000

# %%
df.dtypes # 查看各字段类型
# Out:
# name    object
# team    object
# Q1       int64
# Q2       int64
# Q3       int64
# Q4       int64
# dtype: object

# %%
df.axes # 显示数据行和列名
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')]

# %%
df.index # 查看索引
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.columns # 列名
# Out:
# Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4'], dtype='object')

# %%
# NOTE:建立索引
df.set_index('name', inplace=True) # 建立索引并生效

# %%
df.head()
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84
# Eorge    C  93  96  71  78
# Oah      D  65  49  61  86

# %%
# NOTE:数据选取
df.head(5) # 查看 DataFrame 对象的前n行
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64
# Arry     C  36  37  37  57
# Ack      A  57  60  18  84
# Eorge    C  93  96  71  78
# Oah      D  65  49  61  86

# %%
df.tail(5) # 查看 DataFrame 对象的最后n行
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Gabriel     C  48  59  87  74
# Austin7     C  21  31  30  43
# Lincoln4    C  98  93   1  20
# Eli         E  11  74  58  91
# Ben         E  21  43  41  74

# %%
df.sample(5) # 查看 n 个样本，随机
# Out:
#         team  Q1  Q2  Q3  Q4
# name
# Finley     D  62  73  84  68
# Hunter3    D  38  80  82  40
# Thomas     B  80  48  56  41
# Oah        D  65  49  61  86
# Frankie    B  18  62  52  33

# %%
# 查看指定列
df['Q1']
# df.Q1 # 同上，如果列名符合 python 变量名要求，可使用
# Out:
# name
# Liver       89
# Arry        36
# Ack         57
# Eorge       93
# Oah         65
#             ..
# Gabriel     48
# Austin7     21
# Lincoln4    98
# Eli         11
# Ben         21
# Name: Q1, Length: 100, dtype: int64

# %%
# 选择多列
df[['team', 'Q1']] # 只看这两列，注意括号
# df.loc[:, ['team', 'Q1']] # 和上边效果一样
# Out:
#          team  Q1
# name
# Liver       E  89
# Arry        C  36
# Ack         A  57
# Eorge       C  93
# Oah         D  65
# ...       ...  ..
# Gabriel     C  48
# Austin7     C  21
# Lincoln4    C  98
# Eli         E  11
# Ben         E  21
#
# [100 rows x 2 columns]

# %%
# 用人工索引选取
df[df.index == 'Liver'] # 指定索引
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Liver    E  89  21  24  64

# %%
# 用自然索引选择，类似列表的切片
# df[0:3] # 取前三行,
# df[0:10:2] # 前10个，每两个取一个
df.iloc[:10,:] # 前10个
# Out:
#        team  Q1  Q2  Q3  Q4
# name
# Liver     E  89  21  24  64
# Arry      C  36  37  37  57
# Ack       A  57  60  18  84
# Eorge     C  93  96  71  78
# Oah       D  65  49  61  86
# Harlie    C  24  13  87  43
# Acob      B  61  95  94   8
# Lfie      A   9  10  99  37
# Reddie    D  64  93  57  72
# Oscar     A  77   9  26  67

# %%
# 指定行列
# df.loc['Ben', 'Q1':'Q4'] # 只看 Ben 的四个季度成绩
df.loc['Eorge':'Alexander', 'team':'Q4'] # 指定行区间
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Oah          D  65  49  61  86
# Harlie       C  24  13  87  43
# Acob         B  61  95  94   8
# Lfie         A   9  10  99  37
# Reddie       D  64  93  57  72
# Oscar        A  77   9  26  67
# Leo          B  17   4  33  79
# Logan        B   9  89  35  65
# Archie       C  83  89  59  68
# Theo         C  51  86  87  27
# Thomas       B  80  48  56  41
# James        E  48  77  52  11
# Joshua       A  63   4  80  30
# Henry        A  91  15  75  17
# William      C  80  68   3  26
# Max          E  97  75  41   3
# Lucas        A  60  41  77  62
# Ethan        D  79  45  89  88
# Arthur       A  44  53  42  40
# Mason        D  80  96  26  49
# Isaac        E  74  23  28  65
# Harrison     B  89  13  18  75
# Teddy        E  71  91  21  48
# Finley       D  62  73  84  68
# Daniel       C  50  50  72  61
# Riley        E  35  26  59  83
# Edward       B  57  38  86  87
# Joseph       E  67  87  87  93
# Alexander    C  91  76  26  79

# %%
# 条件选择
# 单一条件
df[df.Q1 > 90] # Q1 列大于90的
df[df.team == 'C'] # team 列为 'C' 的
df[df.index == 'Oscar'] # 指定索引即原数据中的 name
# Out:
#       team  Q1  Q2  Q3  Q4
# name
# Oscar    A  77   9  26  67

# %%
# 组合条件
df[(df['Q1'] > 90) & (df['team'] == 'C')] # and 关系
df[df['team'] == 'C'].loc[df.Q1>90] # 多重筛选
# Out:
#           team  Q1  Q2  Q3  Q4
# name
# Eorge        C  93  96  71  78
# Alexander    C  91  76  26  79
# Lincoln4     C  98  93   1  20

# %%
# 排序
df.sort_values(by='Q1') # 按 Q1 列数据升序排列
df.sort_values(by='Q1', ascending=False) # 降序
df.sort_values(['team', 'Q1'], ascending=[True, False]) # team 升，Q1 降序
# Out:
#          team  Q1  Q2  Q3  Q4
# name
# Aaron       A  96  75  55   8
# Henry       A  91  15  75  17
# Nathan      A  87  77  62  13
# Dylan       A  86  87  65  20
# Blake       A  78  23  93   9
# ...       ...  ..  ..  ..  ..
# Eli         E  11  74  58  91
# Jude        E   8  45  13  65
# Rory9       E   8  12  58  27
# Jackson5    E   6  10  15  33
# Finn        E   4   1  55  32
#
# [100 rows x 5 columns]

# %%
# NOTE:分组聚合
df.groupby('team').sum() # 按团队分组对应列相加
# Out:
#         Q1    Q2    Q3    Q4
# team
# A     1066   639   875   783
# B      975  1218  1202  1136
# C     1056  1194  1068  1127
# D      860  1191  1241  1199
# E      963  1013   881  1033

# %%
df.groupby('team').mean() # 按团队分组对应列求平均
# Out:
#              Q1         Q2         Q3         Q4
# team
# A     62.705882  37.588235  51.470588  46.058824
# B     44.318182  55.363636  54.636364  51.636364
# C     48.000000  54.272727  48.545455  51.227273
# D     45.263158  62.684211  65.315789  63.105263
# E     48.150000  50.650000  44.050000  51.650000

# %%
# 不同列不同的计算方法
df.groupby('team').agg({'Q1': 'sum',  # 总和
                        'Q2': 'count', # 总数
                        'Q3':'mean', # 平均
                        'Q4': 'max'}) # 最大值
# Out:
#         Q1  Q2         Q3  Q4
# team
# A     1066  17  51.470588  97
# B      975  22  54.636364  99
# C     1056  22  48.545455  98
# D      860  19  65.315789  99
# E      963  20  44.050000  98

# %%
# NOTE:数据转换
df.groupby('team').sum().T
# Out:
# team     A     B     C     D     E
# Q1    1066   975  1056   860   963
# Q2     639  1218  1194  1191  1013
# Q3     875  1202  1068  1241   881
# Q4     783  1136  1127  1199  1033

# %%
df.groupby('team').sum().stack()
# Out:
# team
# A     Q1    1066
#       Q2     639
#       Q3     875
#       Q4     783
# B     Q1     975
#       Q2    1218
#       Q3    1202
#       Q4    1136
# C     Q1    1056
#       Q2    1194
#       Q3    1068
#       Q4    1127
# D     Q1     860
#       Q2    1191
#       Q3    1241
#       Q4    1199
# E     Q1     963
#       Q2    1013
#       Q3     881
#       Q4    1033
# dtype: int64

# %%
df.groupby('team').sum().unstack()
# Out:
#     team
# Q1  A       1066
#     B        975
#     C       1056
#     D        860
#     E        963
# Q2  A        639
#     B       1218
#     C       1194
#     D       1191
#     E       1013
# Q3  A        875
#     B       1202
#     C       1068
#     D       1241
#     E        881
# Q4  A        783
#     B       1136
#     C       1127
#     D       1199
#     E       1033
# dtype: int64

# %%
# NOTE: 增加列
# Pandas 增加一列非常方便，就是新定义一个字典的键值一样。
df['one'] = 1 # 增加一个固定值的列
df['total'] = df.Q1 + df.Q2 + df.Q3 + df.Q4 # 增加总成绩列
# 指定一些列相加增加一个新列
df['total'] = df.loc[:,'Q1':'Q4'].apply(lambda x:sum(x), axis=1)
df['total1'] = df.select_dtypes(include='number').sum(axis=1) # 可以把所有为数字的列相加
df['avg'] = df.total/4 # 增加平均成绩列
df
# Out:
#          team  Q1  Q2  Q3  Q4  one  total    avg  total1
# name
# Liver       E  89  21  24  64    1    198  49.50   893.0
# Arry        C  36  37  37  57    1    167  41.75   753.5
# Ack         A  57  60  18  84    1    219  54.75   987.5
# Eorge       C  93  96  71  78    1    338  84.50  1523.0
# Oah         D  65  49  61  86    1    261  65.25  1176.5
# ...       ...  ..  ..  ..  ..  ...    ...    ...     ...
# Gabriel     C  48  59  87  74    1    268  67.00  1208.0
# Austin7     C  21  31  30  43    1    125  31.25   564.5
# Lincoln4    C  98  93   1  20    1    212  53.00   956.0
# Eli         E  11  74  58  91    1    234  58.50  1055.0
# Ben         E  21  43  41  74    1    179  44.75   807.5
#
# [100 rows x 9 columns]

# %%
# NOTE:简单分析
df.select_dtypes(include='number').mean() # 返回所有列的均值
# Out:
# Q1         49.20
# Q2         52.55
# Q3         52.67
# Q4         52.78
# one         1.00
# total     207.20
# avg        51.80
# total1    934.40
# dtype: float64

# %%
df.select_dtypes(include='number').mean(1) # 返回所有行的均值，下同
# Out:
# name
# Liver       167.43750
# Arry        141.28125
# Ack         185.15625
# Eorge       285.56250
# Oah         220.59375
#               ...
# Gabriel     226.50000
# Austin7     105.84375
# Lincoln4    179.25000
# Eli         197.81250
# Ben         151.40625
# Length: 100, dtype: float64

# %%
df.select_dtypes(include='number').corr() # 返回列与列之间的相关系数
# Out:
#               Q1        Q2        Q3        Q4  one     total       avg  \
# Q1      1.000000  0.142088 -0.125436 -0.010781  NaN  0.524435  0.524435
# Q2      0.142088  1.000000  0.056270 -0.033213  NaN  0.594735  0.594735
# Q3     -0.125436  0.056270  1.000000  0.041418  NaN  0.439408  0.439408
# Q4     -0.010781 -0.033213  0.041418  1.000000  NaN  0.473487  0.473487
# one          NaN       NaN       NaN       NaN  NaN       NaN       NaN
# total   0.524435  0.594735  0.439408  0.473487  NaN  1.000000  1.000000
# avg     0.524435  0.594735  0.439408  0.473487  NaN  1.000000  1.000000
# total1  0.524435  0.594735  0.439408  0.473487  NaN  1.000000  1.000000
#
#           total1
# Q1      0.524435
# Q2      0.594735
# Q3      0.439408
# Q4      0.473487
# one          NaN
# total   1.000000
# avg     1.000000
# total1  1.000000

# %%
df.select_dtypes(include='number').count() # 返回每一列中的非空值的个数
# Out:
# Q1        100
# Q2        100
# Q3        100
# Q4        100
# one       100
# total     100
# avg       100
# total1    100
# dtype: int64

# %%
df.select_dtypes(include='number').max() # 返回每一列的最大值
# Out:
# Q1          98.0
# Q2          99.0
# Q3          99.0
# Q4          99.0
# one          1.0
# total      338.0
# avg         84.5
# total1    1523.0
# dtype: float64

# %%
df.select_dtypes(include='number').min() # 返回每一列的最小值
# Out:
# Q1          1.0
# Q2          1.0
# Q3          1.0
# Q4          2.0
# one         1.0
# total      64.0
# avg        16.0
# total1    290.0
# dtype: float64

# %%
df.select_dtypes(include='number').median() # 返回每一列的中位数
# Out:
# Q1         51.50
# Q2         49.50
# Q3         55.00
# Q4         53.00
# one         1.00
# total     203.00
# avg        50.75
# total1    915.50
# dtype: float64

# %%
df.select_dtypes(include='number').std() # 返回每一列的标准差
# Out:
# Q1         29.962603
# Q2         29.845181
# Q3         26.543677
# Q4         27.818524
# one         0.000000
# total      58.298604
# avg        14.574651
# total1    262.343720
# dtype: float64

# %%
df.select_dtypes(include='number').var() # 方差
# Out:
# Q1          897.757576
# Q2          890.734848
# Q3          704.566768
# Q4          773.870303
# one           0.000000
# total      3398.727273
# avg         212.420455
# total1    68824.227273
# dtype: float64

# %%
df.select_dtypes(include='number').mode() # 众数
# Out:
#     Q1  Q2    Q3    Q4  one  total   avg  total1
# 0  9.0  34  87.0  68.0  1.0  198.0  49.5   893.0
# 1  NaN  38   NaN   NaN  NaN    NaN   NaN     NaN

# %%
# NOTE:画图
df['Q1'].plot() # Q1 成绩的折线分布
# Out:
# <Axes: xlabel='name'>

# %%
df.loc['Ben','Q1':'Q4'].plot() # ben 四个季度的成绩变化
# Out:
# <Axes: >

# %%
df.loc[ 'Ben','Q1':'Q4'].plot.bar() # 柱状图
# Out:
# <Axes: >

# %%
df.loc[ 'Ben','Q1':'Q4'].plot.barh() # 横向柱状图
# df.loc['Ben',:]
# Out:
# <Axes: >

# %%
df.groupby('team').sum().T.plot() # 各 Team 四个季度总成绩趋势
# Out:
# <Axes: >

# %%
df.groupby('team').count().Q1.plot.pie() # 各组人数对比
# Out:
# <Axes: ylabel='Q1'>

# %%
# NOTE:输出
df.to_excel('team-done.xlsx') # 导出 excel
df.to_csv('team-done.csv') # 导出 csv
