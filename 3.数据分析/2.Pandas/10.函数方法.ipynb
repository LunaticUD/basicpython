# %%
import pandas as pd

# %%
x = pd.Series([12,10,8,13,6,15,9,11],index=['a','b','c','d','c','e','g','h'])
print(x)
# Out:
# a    12
# b    10
# c     8
# d    13
# c     6
# e    15
# g     9
# h    11
# dtype: int64

# %%
# 输出描述统计值
print(x.describe())
# Out:
# count     8.000000
# mean     10.500000
# std       2.878492
# min       6.000000
# 25%       8.750000
# 50%      10.500000
# 75%      12.250000
# max      15.000000
# dtype: float64
